# %%
import pandas as pd

# %%
df = pd.read_csv('airline_data.csv')

# %%
df.head(20)
# Out:
#           passenger_name  day  month departure_city arrival_city     sales
# 0         VIKTOR BORISOV   21      6         Moscow    Astrakhan   52000.0
# 1         VIKTOR BORISOV   21      6      Astrakhan       Moscow   52000.0
# 2   ALEKSANDRA KUZNECOVA   21      6         Moscow    Astrakhan   52000.0
# 3   ALEKSANDRA KUZNECOVA   21      6      Astrakhan       Moscow   52000.0
# 4      LYUDMILA POTAPOVA   21      6         Moscow  Novosibirsk  178800.0
# 5      LYUDMILA POTAPOVA   21      6         Moscow   Khabarovsk  178800.0
# 6      LYUDMILA POTAPOVA   21      6     Khabarovsk       Moscow  178800.0
# 7      LYUDMILA POTAPOVA   21      6    Novosibirsk       Moscow  178800.0
# 8      MAKSIM KUDRYASHOV   21      6           Perm       Moscow  211100.0
# 9      MAKSIM KUDRYASHOV   21      6         Moscow         Perm  211100.0
# 10     MAKSIM KUDRYASHOV   21      6    Novosibirsk         Perm  211100.0
# 11     MAKSIM KUDRYASHOV   21      6           Perm  Novosibirsk  211100.0
# 12   TATYANA KOLESNIKOVA   21      6         Moscow         Perm  211100.0
# 13   TATYANA KOLESNIKOVA   21      6           Perm  Novosibirsk  211100.0
# 14   TATYANA KOLESNIKOVA   21      6    Novosibirsk         Perm  211100.0
# 15   TATYANA KOLESNIKOVA   21      6           Perm       Moscow  211100.0
# 16        VIKTOR DAVYDOV   21      6         Moscow         Perm  211100.0
# 17        VIKTOR DAVYDOV   21      6    Novosibirsk         Perm  211100.0
# 18        VIKTOR DAVYDOV   21      6           Perm       Moscow  211100.0
# 19        VIKTOR DAVYDOV   21      6           Perm  Novosibirsk  211100.0

# %%
df.columns
# Out:
# Index(['passenger_name', 'day', 'month', 'departure_city', 'arrival_city',
#        'sales'],
#       dtype='object')

# %%
df.passenger_name
# Out:
# 0                VIKTOR BORISOV
# 1                VIKTOR BORISOV
# 2          ALEKSANDRA KUZNECOVA
# 3          ALEKSANDRA KUZNECOVA
# 4             LYUDMILA POTAPOVA
#                    ...
# 1016583        ALEKSANDR ZAYCEV
# 1016584         VALERIY MOISEEV
# 1016585         VALERIY MOISEEV
# 1016586           VASILIY FOMIN
# 1016587           VASILIY FOMIN
# Name: passenger_name, Length: 1016588, dtype: object

# %%
df1 = df[['passenger_name', 'day', 'arrival_city']]

# %%
df1
# Out:
#                passenger_name  day arrival_city
# 0              VIKTOR BORISOV   21    Astrakhan
# 1              VIKTOR BORISOV   21       Moscow
# 2        ALEKSANDRA KUZNECOVA   21    Astrakhan
# 3        ALEKSANDRA KUZNECOVA   21       Moscow
# 4           LYUDMILA POTAPOVA   21  Novosibirsk
# ...                       ...  ...          ...
# 1016583      ALEKSANDR ZAYCEV   15      Bryansk
# 1016584       VALERIY MOISEEV   15      Bryansk
# 1016585       VALERIY MOISEEV   15       Moscow
# 1016586         VASILIY FOMIN   15      Bryansk
# 1016587         VASILIY FOMIN   15       Moscow
#
# [1016588 rows x 3 columns]

# %%
df.tail()
# Out:
#            passenger_name  day  month departure_city arrival_city      sales
# 1016583  ALEKSANDR ZAYCEV   15      8         Moscow      Bryansk  1185800.0
# 1016584   VALERIY MOISEEV   15      8         Moscow      Bryansk  1185800.0
# 1016585   VALERIY MOISEEV   15      8        Bryansk       Moscow  1185800.0
# 1016586     VASILIY FOMIN   15      8         Moscow      Bryansk  1185800.0
# 1016587     VASILIY FOMIN   15      8        Bryansk       Moscow  1185800.0

# %%
display(df.iloc[17])
# Out:
# passenger_name    VIKTOR DAVYDOV
# day                           21
# month                          6
# departure_city       Novosibirsk
# arrival_city                Perm
# sales                   211100.0
# Name: 17, dtype: object

# %%
df.rank()
# Out:
#          passenger_name       day     month  departure_city  arrival_city  \
# 0              899922.5  765354.5   13663.5        413781.5       18649.5
# 1              899922.5  765354.5   13663.5         18254.0      411728.5
# 2               59842.5  765354.5   13663.5        413781.5       18649.5
# 3               59842.5  765354.5   13663.5         18254.0      411728.5
# 4              476508.0  765354.5   13663.5        413781.5      643412.0
# ...                 ...       ...       ...             ...           ...
# 1016583         54982.0  625414.0  843861.5        413781.5       47539.5
# 1016584        871320.5  625414.0  843861.5        413781.5       47539.5
# 1016585        871320.5  625414.0  843861.5         46869.5      411728.5
# 1016586        881409.0  625414.0  843861.5        413781.5       47539.5
# 1016587        881409.0  625414.0  843861.5         46869.5      411728.5
#
#              sales
# 0         327759.0
# 1         327759.0
# 2         327759.0
# 3         327759.0
# 4         861348.0
# ...            ...
# 1016583  1016537.5
# 1016584  1016537.5
# 1016585  1016537.5
# 1016586  1016537.5
# 1016587  1016537.5
#
# [1016588 rows x 6 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of                passenger_name  day  month departure_city arrival_city  \
# 0              VIKTOR BORISOV   21      6         Moscow    Astrakhan
# 1              VIKTOR BORISOV   21      6      Astrakhan       Moscow
# 2        ALEKSANDRA KUZNECOVA   21      6         Moscow    Astrakhan
# 3        ALEKSANDRA KUZNECOVA   21      6      Astrakhan       Moscow
# 4           LYUDMILA POTAPOVA   21      6         Moscow  Novosibirsk
# ...                       ...  ...    ...            ...          ...
# 1016583      ALEKSANDR ZAYCEV   15      8         Moscow      Bryansk
# 1016584       VALERIY MOISEEV   15      8         Moscow      Bryansk
# 1016585       VALERIY MOISEEV   15      8        Bryansk       Moscow
# 1016586         VASILIY FOMIN   15      8         Moscow      Bryansk
# 1016587         VASILIY FOMIN   15      8        Bryansk       Moscow
#
#              sales
# 0          52000.0
# 1          52000.0
# 2          52000.0
# 3          52000.0
# 4         178800.0
# ...            ...
# 1016583  1185800.0
# 1016584  1185800.0
# 1016585  1185800.0
# 1016586  1185800.0
# 1016587  1185800.0
#
# [1016588 rows x 6 columns]>

# %%
df.shape
# Out:
# (1016588, 6)

# %%
df.size
# Out:
# 6099528

# %%
round(df.sales.mean(),2)
# Out:
# 106188.27

# %%
df1 = df.sample(15)

# %%
df1
# Out:
#             passenger_name  day  month    departure_city    arrival_city  \
# 133453       IRINA KOZLOVA    6      7          Kemorovo          Moscow
# 383993       ALISA VOLKOVA   18      7             Kirov     Novosibirsk
# 504899    IRINA KONOVALOVA   24      7            Moscow     Arkhangelsk
# 662566    MIKHAIL GORBUNOV   31      7         Volgograd          Rostov
# 946677     ANDREY GRIGOREV   13      8  Nizhniy Novgorod  St. Petersburg
# 565183   EVDOKIYA LOGINOVA   27      7            Samara          Moscow
# 600395  NATALIYA RODIONOVA   28      7            Moscow           Tomsk
# 347279       ANNA SERGEEVA   16      7       Chelyabinsk       Volgograd
# 601139  VALENTINA VASILEVA   28      7         Sovetskiy          Moscow
# 831805     VASILIY KISELEV    8      8            Moscow           Sochi
# 336436      ILONA SOKOLOVA   16      7            Moscow  St. Petersburg
# 650466     ALEKSEY SAVELEV   31      7       Kaliningrad          Moscow
# 252832    NADEZHDA KOZLOVA   12      7       Novosibirsk          Moscow
# 935624      NIKOLAY EGOROV   12      8            Moscow  St. Petersburg
# 510798     SERGEY TIKHONOV   24      7     Yekaterinburg          Moscow
#
#            sales
# 133453  181100.0
# 383993   84500.0
# 504899   40400.0
# 662566   94700.0
# 946677   35600.0
# 565183   16400.0
# 600395  115700.0
# 347279  159300.0
# 601139  124300.0
# 831805   56000.0
# 336436   51900.0
# 650466   21400.0
# 252832   62100.0
# 935624  126600.0
# 510798   73600.0

# %%
import matplotlib.pyplot as plt
sales = df1['sales']
months = df1['month']
plt.bar(months,sales)
plt.ylabel('Sales')
plt.xlabel('Summer Months')
plt.show()

# %%
df2 = df.sample(100)

# %%
df2
# Out:
#             passenger_name  day  month     departure_city    arrival_city  \
# 869197       IVAN MELNIKOV    9      8  Yuzhno-Sakhalinsk          Moscow
# 590976     DMITRIY SOROKIN   28      7             Moscow  St. Petersburg
# 124212  RUZALIYA TROFIMOVA    6      7     St. Petersburg           Kirov
# 2401       VLADIMIR FROLOV   26      6             Moscow     Novosibirsk
# 854242    LIDIYA TIKHONOVA    9      8              Sochi          Moscow
# ...                    ...  ...    ...                ...             ...
# 429408     MIKHAIL KULIKOV   20      7             Moscow     Novosibirsk
# 65430         ELENA ISAEVA    3      7             Moscow            Perm
# 266814         NINA POPOVA   13      7             Moscow           Anapa
# 280663      SERGEY SAVELEV   13      7        Krasnoyarsk          Moscow
# 788574      DMITRIY OSIPOV    6      8             Surgut   Yekaterinburg
#
#            sales
# 869197  532800.0
# 590976   45400.0
# 124212   62600.0
# 2401    207200.0
# 854242   56000.0
# ...          ...
# 429408  111600.0
# 65430    70700.0
# 266814   24400.0
# 280663  133100.0
# 788574   61900.0
#
# [100 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
sales = df2['sales']
months = df2['month']
plt.bar(months,sales)
plt.xticks(months, rotation = 'horizontal', size = 10)
plt.ylabel('Sales')
plt.xlabel('Summer Months')
plt.show()

# %%
df3 = df.sample(500)

# %%
import matplotlib.pyplot as plt
sales = df3['sales']
months = df3['month']
plt.bar(months,sales)
plt.xticks(months, rotation = 'horizontal', size = 10)
plt.ylabel('Sales')
plt.xlabel('Summer Months')
plt.show()

# %%
df4 = df.sample(1000)

# %%
import matplotlib.pyplot as plt
sales = df4['sales']
months = df4['month']
plt.bar(months,sales)
plt.xticks(months, rotation = 'horizontal', size = 10)
plt.ylabel('Sales')
plt.xlabel('Summer Months')
plt.show()

# %%
df5 = df.sample(5000)

# %%
import matplotlib.pyplot as plt
sales = df5['sales']
months = df5['month']
plt.bar(months,sales)
plt.xticks(months, rotation = 'horizontal', size = 10)
plt.ylabel('Sales')
plt.xlabel('Summer Months')
plt.show()

# %%
df6 = df.sample(10000)

# %%
import matplotlib.pyplot as plt
sales = df6['sales']
months = df6['month']
plt.bar(months,sales)
plt.xticks(months, rotation = 'horizontal', size = 10)
plt.ylabel('Sales')
plt.xlabel('Summer Months')
plt.show()

# %% [markdown]
# Conclusion:
#
# July is the busiest month of year for tarvelling by air as total sales of ticket booking is highest in this month. after jul
